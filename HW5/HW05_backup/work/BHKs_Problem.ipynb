# %%
import random
import scipy, scipy.stats

# %%
Ps = np.linspace(0, .01, 10000)
#Mk1s
N1 = 26751
N1_kills = 183
y1 = dist.pdf(Ps, 1 + N1_kills, 1 + N1 - N1_kills);

#Mk2s
N2 = 27079
N2_kills = 222
y2 = dist.pdf(Ps, 1 + N2_kills, 1 + N2 - N2_kills);

plot(Ps, y1, color="grey", ls = "--");
plot(Ps, y2, color="grey"); 

fill_between(Ps,0, y2, color="#00dd2f", alpha=0.25);
fill_between(Ps,0, y1, color="#ffdb00", alpha=0.25);

xlim([0,0.015])
title("Bayesian Hunter Killer Kill Rates")
legend(["Mk1s","Mk2s"])
savefig("BHK_Plots.png")
